# %%
import pandas as pd

# %%
data = pd.Series([10, 20, 30, 40, 50])
# Creates a series of data with the values 10, 20, 30, 40, 50

# %%
data
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 30, 22, 35, 28],
    'City': ['New York', 'Los Angeles', 'Chicago', 'San Francisco', 'Miami']
}
# Creates a dataframe with the values in the data dictionary (Table)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   22        Chicago
# 3    David   35  San Francisco
# 4      Eve   28          Miami

# %%
# THESE ARE THE FUNCTIONS TO READ DATA FROM VARIOUS SOURCES
# pd.read_csv('data.csv')
# pd.read_excel('data.xlsx')
# pd.read_json('data.json')
# pd.read_html('data.html')
# pd.read_sql('data.sql')
# pd.read_csv('data.csv', sep='\t')

# %%
sample_data_new = pd.read_csv('sample_data.csv')

# %%
sample_data_new
# Out:
#                   Name                        Email                 Phone  \
# 0            Lisa West         andrew23@example.com         (465)852-8470
# 1           Jason Cole        kenneth05@example.net            7783540568
# 2          Juan Crosby          zbarnes@example.org   (676)328-6244x05295
# 3           April Ball  michaelmckinney@example.com  +1-633-685-4901x2113
# 4       Donald Jackson        peterdean@example.com          779-437-7643
# ..                 ...                          ...                   ...
# 195     Willie Shelton       jamesdavis@example.net      277-426-9077x821
# 196  Deborah Nicholson       michelle15@example.net     954-765-9968x1900
# 197         Vanessa Wu    reginaldowens@example.com  +1-682-798-1566x9050
# 198        Robyn Allen           chad33@example.org      212-239-3934x599
# 199      Scott Stewart        valerie39@example.com          956.897.0540
#
#                                                Address           City  \
# ...

# %%
sample_data_new.info
# Out:
# <bound method DataFrame.info of                   Name                        Email                 Phone  \
# 0            Lisa West         andrew23@example.com         (465)852-8470
# 1           Jason Cole        kenneth05@example.net            7783540568
# 2          Juan Crosby          zbarnes@example.org   (676)328-6244x05295
# 3           April Ball  michaelmckinney@example.com  +1-633-685-4901x2113
# 4       Donald Jackson        peterdean@example.com          779-437-7643
# ..                 ...                          ...                   ...
# 195     Willie Shelton       jamesdavis@example.net      277-426-9077x821
# 196  Deborah Nicholson       michelle15@example.net     954-765-9968x1900
# 197         Vanessa Wu    reginaldowens@example.com  +1-682-798-1566x9050
# 198        Robyn Allen           chad33@example.org      212-239-3934x599
# 199      Scott Stewart        valerie39@example.com          956.897.0540
#
# ...
